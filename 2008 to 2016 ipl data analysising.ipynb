# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('deliveries.csv')

# %%
df
# Out:
#         match_id  inning                 batting_team  \
# 0              1       1          Sunrisers Hyderabad
# 1              1       1          Sunrisers Hyderabad
# 2              1       1          Sunrisers Hyderabad
# 3              1       1          Sunrisers Hyderabad
# 4              1       1          Sunrisers Hyderabad
# 5              1       1          Sunrisers Hyderabad
# 6              1       1          Sunrisers Hyderabad
# 7              1       1          Sunrisers Hyderabad
# 8              1       1          Sunrisers Hyderabad
# 9              1       1          Sunrisers Hyderabad
# 10             1       1          Sunrisers Hyderabad
# 11             1       1          Sunrisers Hyderabad
# 12             1       1          Sunrisers Hyderabad
# 13             1       1          Sunrisers Hyderabad
# 14             1       1          Sunrisers Hyderabad
# 15             1       1          Sunrisers Hyderabad
# ...

# %%
df.shape
# Out:
# (150460, 21)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150460 entries, 0 to 150459
# Data columns (total 21 columns):
# match_id            150460 non-null int64
# inning              150460 non-null int64
# batting_team        150460 non-null object
# bowling_team        150460 non-null object
# over                150460 non-null int64
# ball                150460 non-null int64
# batsman             150460 non-null object
# non_striker         150460 non-null object
# bowler              150460 non-null object
# is_super_over       150460 non-null int64
# wide_runs           150460 non-null int64
# bye_runs            150460 non-null int64
# legbye_runs         150460 non-null int64
# noball_runs         150460 non-null int64
# penalty_runs        150460 non-null int64
# batsman_runs        150460 non-null int64
# extra_runs          150460 non-null int64
# total_runs          150460 non-null int64
# player_dismissed    7438 non-null object
# dismissal_kind      7438 non-null object
# ...

# %%
df.isnull().sum()
# Out:
# match_id                 0
# inning                   0
# batting_team             0
# bowling_team             0
# over                     0
# ball                     0
# batsman                  0
# non_striker              0
# bowler                   0
# is_super_over            0
# wide_runs                0
# bye_runs                 0
# legbye_runs              0
# noball_runs              0
# penalty_runs             0
# batsman_runs             0
# extra_runs               0
# total_runs               0
# player_dismissed    143022
# dismissal_kind      143022
# fielder             145091
# dtype: int64

# %%
per = len(df)*0.1
per
# Out:
# 15046.0

# %%
df.replace(np.nan, 'PlayerNotAvailable', inplace=True)

# %%
df
# Out:
#         match_id  inning                 batting_team  \
# 0              1       1          Sunrisers Hyderabad
# 1              1       1          Sunrisers Hyderabad
# 2              1       1          Sunrisers Hyderabad
# 3              1       1          Sunrisers Hyderabad
# 4              1       1          Sunrisers Hyderabad
# 5              1       1          Sunrisers Hyderabad
# 6              1       1          Sunrisers Hyderabad
# 7              1       1          Sunrisers Hyderabad
# 8              1       1          Sunrisers Hyderabad
# 9              1       1          Sunrisers Hyderabad
# 10             1       1          Sunrisers Hyderabad
# 11             1       1          Sunrisers Hyderabad
# 12             1       1          Sunrisers Hyderabad
# 13             1       1          Sunrisers Hyderabad
# 14             1       1          Sunrisers Hyderabad
# 15             1       1          Sunrisers Hyderabad
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150460 entries, 0 to 150459
# Data columns (total 21 columns):
# match_id            150460 non-null int64
# inning              150460 non-null int64
# batting_team        150460 non-null object
# bowling_team        150460 non-null object
# over                150460 non-null int64
# ball                150460 non-null int64
# batsman             150460 non-null object
# non_striker         150460 non-null object
# bowler              150460 non-null object
# is_super_over       150460 non-null int64
# wide_runs           150460 non-null int64
# bye_runs            150460 non-null int64
# legbye_runs         150460 non-null int64
# noball_runs         150460 non-null int64
# penalty_runs        150460 non-null int64
# batsman_runs        150460 non-null int64
# extra_runs          150460 non-null int64
# total_runs          150460 non-null int64
# player_dismissed    150460 non-null object
# ...

# %%
x = df.batting_team.value_counts()
x
# Out:
# Mumbai Indians                 18943
# Royal Challengers Bangalore    17678
# Kings XI Punjab                17594
# Kolkata Knight Riders          17229
# Delhi Daredevils               17185
# Chennai Super Kings            15754
# Rajasthan Royals               13914
# Sunrisers Hyderabad             9058
# Deccan Chargers                 9034
# Pune Warriors                   5443
# Gujarat Lions                   3566
# Rising Pune Supergiant          1900
# Kochi Tuskers Kerala            1582
# Rising Pune Supergiants         1580
# Name: batting_team, dtype: int64

# %%
# %matplotlib inline
x.plot(kind='bar',figsize=(16,13))

# %%
y = df.bowling_team.value_counts()
y
# Out:
# Mumbai Indians                 18879
# Royal Challengers Bangalore    17920
# Kolkata Knight Riders          17411
# Kings XI Punjab                17392
# Delhi Daredevils               17099
# Chennai Super Kings            15562
# Rajasthan Royals               14111
# Deccan Chargers                 9039
# Sunrisers Hyderabad             8888
# Pune Warriors                   5457
# Gujarat Lions                   3545
# Rising Pune Supergiant          1928
# Rising Pune Supergiants         1615
# Kochi Tuskers Kerala            1614
# Name: bowling_team, dtype: int64

# %%
y.plot(kind='bar',figsize=(8,4))

# %%
df.columns
# Out:
# Index(['match_id', 'inning', 'batting_team', 'bowling_team', 'over', 'ball',
#        'batsman', 'non_striker', 'bowler', 'is_super_over', 'wide_runs',
#        'bye_runs', 'legbye_runs', 'noball_runs', 'penalty_runs',
#        'batsman_runs', 'extra_runs', 'total_runs', 'player_dismissed',
#        'dismissal_kind', 'fielder'],
#       dtype='object')

# %%
df.head()
# Out:
#    match_id  inning         batting_team                 bowling_team  over  \
# 0         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 1         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 2         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 3         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 4         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
#
#    ball    batsman non_striker    bowler  is_super_over  ...  bye_runs  \
# 0     1  DA Warner    S Dhawan  TS Mills              0  ...         0
# 1     2  DA Warner    S Dhawan  TS Mills              0  ...         0
# 2     3  DA Warner    S Dhawan  TS Mills              0  ...         0
# 3     4  DA Warner    S Dhawan  TS Mills              0  ...         0
# 4     5  DA Warner    S Dhawan  TS Mills              0  ...         0
#
#    legbye_runs  noball_runs  penalty_runs  batsman_runs  extra_runs  \
# ...

# %%
d = pd.crosstab(df['batting_team'] ,df['total_runs'])
d
# Out:
# total_runs                      0     1     2   3     4   5    6   7
# batting_team
# Chennai Super Kings          5382  6570  1163  72  1792  33  740   2
# Deccan Chargers              3227  3788   593  39   966  21  397   3
# Delhi Daredevils             6097  7143  1163  63  1991  41  683   4
# Gujarat Lions                1155  1536   242   9   460   9  155   0
# Kings XI Punjab              6187  7199  1227  68  2119  32  759   3
# Kochi Tuskers Kerala          595   656    93   7   172   6   51   2
# Kolkata Knight Riders        6046  7288  1105  65  2014  52  657   2
# Mumbai Indians               6821  7760  1202  76  2171  37  872   4
# Pune Warriors                2099  2219   373  19   526  11  195   1
# Rajasthan Royals             5111  5519   994  72  1651  29  535   3
# Rising Pune Supergiant        616   861   129   4   200   1   89   0
# Rising Pune Supergiants       521   685   123   9   173   1   68   0
# ...

# %%
d[0].plot(kind= 'pie',subplots=True,figsize=(10,10) )
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x00000250EC654BA8>],
#       dtype=object)

# %%
df.bye_runs.sum()
# Out:
# 735

# %%
df.columns
# Out:
# Index(['match_id', 'inning', 'batting_team', 'bowling_team', 'over', 'ball',
#        'batsman', 'non_striker', 'bowler', 'is_super_over', 'wide_runs',
#        'bye_runs', 'legbye_runs', 'noball_runs', 'penalty_runs',
#        'batsman_runs', 'extra_runs', 'total_runs', 'player_dismissed',
#        'dismissal_kind', 'fielder'],
#       dtype='object')

# %%
df2 = df.groupby('batting_team')
df2.get_group('Mumbai Indians').head()
# Out:
#      match_id  inning    batting_team            bowling_team  over  ball  \
# 248         2       1  Mumbai Indians  Rising Pune Supergiant     1     1
# 249         2       1  Mumbai Indians  Rising Pune Supergiant     1     2
# 250         2       1  Mumbai Indians  Rising Pune Supergiant     1     3
# 251         2       1  Mumbai Indians  Rising Pune Supergiant     1     4
# 252         2       1  Mumbai Indians  Rising Pune Supergiant     1     5
#
#         batsman non_striker    bowler  is_super_over  ...  bye_runs  \
# 248    PA Patel  JC Buttler  AB Dinda              0  ...         0
# 249    PA Patel  JC Buttler  AB Dinda              0  ...         0
# 250    PA Patel  JC Buttler  AB Dinda              0  ...         0
# 251  JC Buttler    PA Patel  AB Dinda              0  ...         0
# 252    PA Patel  JC Buttler  AB Dinda              0  ...         0
#
#      legbye_runs  noball_runs  penalty_runs  batsman_runs  extra_runs  \
# ...

# %%
pd.crosstab(df.batsman, df.bye_runs )
# Out:
# bye_runs                 0  1  2  3  4
# batsman
# A Ashish Reddy         194  1  0  0  1
# A Chandila               7  0  0  0  0
# A Chopra                75  0  0  0  0
# A Choudhary             20  0  0  0  0
# A Flintoff              57  0  0  0  0
# A Kumble                48  0  0  0  1
# A Mishra               378  3  0  0  1
# A Mithun                25  0  1  0  0
# A Mukund                23  0  0  0  0
# A Nehra                 60  3  0  0  0
# A Singh                 10  0  0  0  0
# A Symonds              779  1  0  0  1
# A Uniyal                 7  0  0  0  0
# A Zampa                  8  0  0  0  0
# AA Bilakhia             88  0  0  0  0
# AA Chavan               11  0  0  0  0
# AA Jhunjhunwala        218  0  0  0  0
# AA Noffke               12  0  0  0  0
# AB Agarkar             158  2  0  0  0
# AB Barath               43  0  0  0  0
# AB Dinda                49  1  0  0  0
# AB McDonald            102  1  0  0  0
# AB de Villiers        2395  3  1  0  3
# ...

# %%
df3 = pd.crosstab(df['bowler'], df['noball_runs'])
df3
# Out:
# noball_runs           0   1  2  3  5
# bowler
# A Ashish Reddy      268   2  0  0  0
# A Chandila          234   0  0  0  0
# A Choudhary         107   1  0  0  0
# A Flintoff           66   0  0  0  0
# A Kumble            978   5  0  0  0
# A Mishra           2683  20  0  0  0
# A Mithun            303   9  0  0  0
# A Nehra            1965   9  0  0  0
# A Nel                18   0  0  0  0
# A Singh             485   1  0  0  0
# A Symonds           539   1  0  0  0
# A Uniyal             38   0  0  0  0
# A Zampa             225   0  0  0  0
# AA Chavan           255   0  0  0  0
# AA Jhunjhunwala      88   0  0  0  0
# AA Kazi              13   0  0  0  0
# AA Noffke            25   0  0  0  0
# AB Agarkar          818   2  0  0  0
# AB Dinda           1575  14  0  0  0
# AB McDonald         188   0  0  0  0
# AC Gilchrist          1   0  0  0  0
# AC Thomas           325   2  0  0  0
# AC Voges             56   0  0  0  0
# AD Mascarenhas      310   0  0  0  0
# ...

# %%
from IPython.display import YouTubeVideo
YouTubeVideo('')
# Out:
#         <iframe
#             width="400"
#             height="300"
#             src="https://www.youtube.com/embed/"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %%
df2 = pd.read_csv('matches.csv')

# %%
3df2
# Out:
#       id  season           city        date                        team1  \
# 0      1    2017      Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1      2    2017           Pune  2017-04-06               Mumbai Indians
# 2      3    2017         Rajkot  2017-04-07                Gujarat Lions
# 3      4    2017         Indore  2017-04-08       Rising Pune Supergiant
# 4      5    2017      Bangalore  2017-04-08  Royal Challengers Bangalore
# 5      6    2017      Hyderabad  2017-04-09                Gujarat Lions
# 6      7    2017         Mumbai  2017-04-09        Kolkata Knight Riders
# 7      8    2017         Indore  2017-04-10  Royal Challengers Bangalore
# 8      9    2017           Pune  2017-04-11             Delhi Daredevils
# 9     10    2017         Mumbai  2017-04-12          Sunrisers Hyderabad
# 10    11    2017        Kolkata  2017-04-13              Kings XI Punjab
# 11    12    2017      Bangalore  2017-04-14  Royal Challengers Bangalore
# ...

# %% [markdown]
# # finding maximum time win team name
# # make analysis to make a money like in gambling
# # finding toss win team what the decision has to like fielding or batting
# # finding weakest team in the data set
# # checking in which city more matches occure
# # Which team won IPL How many times?

# %%
x = df2.winner.value_counts()
x
# Out:
# Mumbai Indians                 92
# Chennai Super Kings            79
# Kolkata Knight Riders          77
# Royal Challengers Bangalore    73
# Kings XI Punjab                70
# Rajasthan Royals               63
# Delhi Daredevils               62
# Sunrisers Hyderabad            42
# Deccan Chargers                29
# Gujarat Lions                  13
# Pune Warriors                  12
# Rising Pune Supergiant         10
# Kochi Tuskers Kerala            6
# Rising Pune Supergiants         5
# Name: winner, dtype: int64

# %% [markdown]
# # as you can see that the more time winning time is mumbai indians

# %%
# %matplotlib inline
x.plot(kind= 'bar')

# %%
pd.crosstab(df2.winner, df2.season, margins=True)
# Out:
# season                       2008  2009  2010  2011  2012  2013  2014  2015  \
# winner
# Chennai Super Kings             9     8     9    11    10    12    10    10
# Deccan Chargers                 2     9     8     6     4     0     0     0
# Delhi Daredevils                7    10     7     4    11     3     2     5
# Gujarat Lions                   0     0     0     0     0     0     0     0
# Kings XI Punjab                10     7     4     7     8     8    12     3
# Kochi Tuskers Kerala            0     0     0     6     0     0     0     0
# Kolkata Knight Riders           6     3     7     8    12     6    11     7
# Mumbai Indians                  7     5    11    10    10    13     7    10
# Pune Warriors                   0     0     0     4     4     4     0     0
# Rajasthan Royals               13     6     6     6     7    11     7     7
# Rising Pune Supergiant          0     0     0     0     0     0     0     0
# ...

# %%
g = pd.crosstab(df2.toss_winner, df2.toss_decision, margins=True, normalize='index')
g
# Out:
# toss_decision                     bat     field
# toss_winner
# Chennai Super Kings          0.666667  0.333333
# Deccan Chargers              0.558140  0.441860
# Delhi Daredevils             0.361111  0.638889
# Gujarat Lions                0.066667  0.933333
# Kings XI Punjab              0.367647  0.632353
# Kochi Tuskers Kerala         0.375000  0.625000
# Kolkata Knight Riders        0.384615  0.615385
# Mumbai Indians               0.470588  0.529412
# Pune Warriors                0.550000  0.450000
# Rajasthan Royals             0.444444  0.555556
# Rising Pune Supergiant       0.000000  1.000000
# Rising Pune Supergiants      0.428571  0.571429
# Royal Challengers Bangalore  0.285714  0.714286
# Sunrisers Hyderabad          0.514286  0.485714
# All                          0.429245  0.570755

# %%
g.plot(kind = 'bar',subplots='True')
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x00000250EC864588>,
# ...
#       dtype=object)

# %%
according_to_toss_win_no = pd.crosstab(df2.toss_decision, df2.result)
according_to_toss_win_no
# Out:
# result         no result  normal  tie
# toss_decision
# bat                    1     269    3
# field                  2     357    4

# %%
according_to_toss_win_no.plot(kind='bar')

# %%
df2
# Out:
#       id  season           city        date                        team1  \
# 0      1    2017      Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1      2    2017           Pune  2017-04-06               Mumbai Indians
# 2      3    2017         Rajkot  2017-04-07                Gujarat Lions
# 3      4    2017         Indore  2017-04-08       Rising Pune Supergiant
# 4      5    2017      Bangalore  2017-04-08  Royal Challengers Bangalore
# 5      6    2017      Hyderabad  2017-04-09                Gujarat Lions
# 6      7    2017         Mumbai  2017-04-09        Kolkata Knight Riders
# 7      8    2017         Indore  2017-04-10  Royal Challengers Bangalore
# 8      9    2017           Pune  2017-04-11             Delhi Daredevils
# 9     10    2017         Mumbai  2017-04-12          Sunrisers Hyderabad
# 10    11    2017        Kolkata  2017-04-13              Kings XI Punjab
# 11    12    2017      Bangalore  2017-04-14  Royal Challengers Bangalore
# ...

# %%
every_matches_count = df2.season.value_counts(sort=False)
every_matches_count
# Out:
# 2008    58
# 2009    57
# 2010    60
# 2011    73
# 2012    74
# 2013    76
# 2014    60
# 2015    59
# 2016    60
# 2017    59
# Name: season, dtype: int64

# %%
every_matches_count.plot(kind = 'bar')

# %%
g = df2['player_of_match'].value_counts().max()
df2[:][df2['player_of_match']== g]
# Out:
# Empty DataFrame
# Columns: [id, season, city, date, team1, team2, toss_winner, toss_decision, result, dl_applied, winner, win_by_runs, win_by_wickets, player_of_match, venue, umpire1, umpire2, umpire3]
# Index: []

# %%
df2['player_of_match'].value_counts()
# Out:
# CH Gayle             18
# YK Pathan            16
# AB de Villiers       15
# DA Warner            15
# SK Raina             14
# RG Sharma            14
# MS Dhoni             13
# G Gambhir            13
# AM Rahane            12
# MEK Hussey           12
# DR Smith             11
# V Sehwag             11
# V Kohli              11
# SR Watson            10
# JH Kallis            10
# SE Marsh              9
# KA Pollard            9
# A Mishra              9
# SR Tendulkar          8
# RA Jadeja             7
# RV Uthappa            7
# AC Gilchrist          7
# AT Rayudu             7
# UT Yadav              6
# A Nehra               6
# Harbhajan Singh       6
# SP Narine             6
# AD Russell            6
# BJ Hodge              6
# M Vijay               6
#                      ..
# AD Mascarenhas        1
# Mohammed Shami        1
# KK Cooper             1
# J Theron              1
# GD McGrath            1
# A Chandila            1
# PD Collingwood        1
# ...

# %%
pd.crosstab(df2.city, df2.season, margins=True)
# Out:
# season          2008  2009  2010  2011  2012  2013  2014  2015  2016  2017  \
# city
# Abu Dhabi          0     0     0     0     0     0     7     0     0     0
# Ahmedabad          0     0     4     0     0     0     4     4     0     0
# Bangalore          7     0     7     6     8     8     6     7     9     8
# Bloemfontein       0     2     0     0     0     0     0     0     0     0
# Cape Town          0     7     0     0     0     0     0     0     0     0
# Centurion          0    12     0     0     0     0     0     0     0     0
# Chandigarh         7     0     5     4     6     6     3     4     7     4
# Chennai            7     0     7     9    10     8     0     7     0     0
# Cuttack            0     0     2     0     2     0     3     0     0     0
# Delhi              6     0     7     7     8     8     5     5     7     7
# Dharamsala         0     0     2     3     2     2     0     0     0     0
# ...

# %%
pd.crosstab(df2.winner, df2.city)
# Out:
# city                         Abu Dhabi  Ahmedabad  Bangalore  Bloemfontein  \
# winner
# Chennai Super Kings                  1          0          4             0
# Deccan Chargers                      0          0          1             0
# Delhi Daredevils                     0          1          3             1
# Gujarat Lions                        0          0          1             0
# Kings XI Punjab                      2          1          5             1
# Kochi Tuskers Kerala                 0          0          0             0
# Kolkata Knight Riders                1          0          6             0
# Mumbai Indians                       0          1          8             0
# Pune Warriors                        0          0          0             0
# Rajasthan Royals                     3          7          3             0
# Rising Pune Supergiant               0          0          1             0
# ...

# %%
 df2.city.value_counts()
# Out:
# Mumbai            85
# Bangalore         66
# Kolkata           61
# Delhi             60
# Hyderabad         49
# Chennai           48
# Chandigarh        46
# Jaipur            33
# Pune              32
# Durban            15
# Ahmedabad         12
# Centurion         12
# Visakhapatnam     11
# Rajkot            10
# Dharamsala         9
# Johannesburg       8
# Abu Dhabi          7
# Cuttack            7
# Cape Town          7
# Port Elizabeth     7
# Ranchi             7
# Sharjah            6
# Raipur             6
# Kochi              5
# Indore             5
# Kanpur             4
# Kimberley          3
# East London        3
# Nagpur             3
# Bloemfontein       2
# Name: city, dtype: int64

# %%
df2.head()
# Out:
#    id  season       city        date                        team1  \
# 0   1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1   2    2017       Pune  2017-04-06               Mumbai Indians
# 2   3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3   4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4   5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# 2        Kolkata Knight Riders        Kolkata Knight Riders         field
# 3              Kings XI Punjab              Kings XI Punjab         field
# 4             Delhi Daredevils  Royal Challengers Bangalore           bat
#
#    result  dl_applied                       winner  win_by_runs  \
# ...

# %%
total_match_play_by_teams = df2.team1.value_counts(sort=False) + df2.team2.value_counts(sort=False)
total_match_play_by_teams
# Out:
# Mumbai Indians                 157
# Gujarat Lions                   30
# Kochi Tuskers Kerala            14
# Royal Challengers Bangalore    152
# Deccan Chargers                 75
# Kings XI Punjab                148
# Chennai Super Kings            131
# Rajasthan Royals               118
# Pune Warriors                   46
# Rising Pune Supergiants         14
# Kolkata Knight Riders          148
# Sunrisers Hyderabad             76
# Delhi Daredevils               147
# Rising Pune Supergiant          16
# dtype: int64

# %%
winner_chart = df2.winner.value_counts(sort=False)
winner_chart
# Out:
# Mumbai Indians                 92
# Gujarat Lions                  13
# Kochi Tuskers Kerala            6
# Royal Challengers Bangalore    73
# Deccan Chargers                29
# Kings XI Punjab                70
# Chennai Super Kings            79
# Rajasthan Royals               63
# Pune Warriors                  12
# Rising Pune Supergiants         5
# Kolkata Knight Riders          77
# Sunrisers Hyderabad            42
# Delhi Daredevils               62
# Rising Pune Supergiant         10
# Name: winner, dtype: int64

# %%
plt.figure(figsize=(10,7))
plt.plot(total_match_play_by_teams,'b*', label='bluestar')
plt.plot(winner_chart, 'bo', label='GreenDots')
plt.title('A Simple Scatterplot')
plt.xlabel('X')
plt.ylabel('Y')
plt.legend(loc='best')
plt.show()

# %%
total_match_play_by_teams - df2.winner.value_counts(sort=False)
# Out:
# Mumbai Indians                 65
# Gujarat Lions                  17
# Kochi Tuskers Kerala            8
# Royal Challengers Bangalore    79
# Deccan Chargers                46
# Kings XI Punjab                78
# Chennai Super Kings            52
# Rajasthan Royals               55
# Pune Warriors                  34
# Rising Pune Supergiants         9
# Kolkata Knight Riders          71
# Sunrisers Hyderabad            34
# Delhi Daredevils               85
# Rising Pune Supergiant          6
# dtype: int64

# %%
import matplotlib.pyplot as plt
t = np.arange(256)
sp = np.fft.fft(np.sin(t))

# %%
plt.plot(sp)
# Out:
# C:\Users\bala prajapati\AppData\Local\Continuum\anaconda3\lib\site-packages\numpy\core\numeric.py:538: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)
